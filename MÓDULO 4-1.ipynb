# %%
def find_smallest_int(arr):
    return min(arr)

# %%
def find_average(nums):
    soma = 0
    if len(nums) == 0:
        return 0
    elif not nums:
        return 0
    else:
        for i in nums:
            soma = soma + i
            media = soma / len(nums)
        return media

# %%
a = (1, 2, 3, 4)
b = ('a', 5, 'b', 6)
c = a + b
print(c)
# Out:
# (1, 2, 3, 4, 'a', 5, 'b', 6)
