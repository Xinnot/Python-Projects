# %% [markdown]
# Lista e Strings

# %%
lista1 = [10, 20, 30, 40]
type(lista1)
# Out:
# list

# %%
lista1[0]
# Out:
# 10

# %%
lista1[1]
# Out:
# 20

# %%
lista1[2]
# Out:
# 30

# %%
for numero in lista1: 
  dobro = numero * 2
  print(numero)
  print(dobro)
  print('----')
# Out:
# 10
# 20
# ----
# 20
# 40
# ----
# 30
# 60
# ----
# 40
# 80
# ----

# %%
zombies = ['z1', 'z2', 'z3', 'z4']

for zombie in zombies:
  print('Nome: ', zombie)
# Out:
# Nome:  z1
# Nome:  z2
# Nome:  z3
# Nome:  z4

# %%
print(zombies)
zombies.sort()
print(zombies)
# Out:
# ['z1', 'z2', 'z3', 'z4']
# ['z1', 'z2', 'z3', 'z4']

# %%
zombies[1:3]
# Out:
# ['z2', 'z3']

# %%
nome = 'Daniel da Kenzie'
nomes = 'Everton'
print(nome[0:4])
print(nomes[4:7])
# Out:
# Dani
# ton

# %%
nome.upper()
# Out:
# 'DANIEL DA KENZIE'

# %%
nome.title()
# Out:
# 'Daniel Da Kenzie'

# %%
for letra in nome:
  print('Letra:', letra)
# Out:
# Letra: D
# Letra: a
# Letra: n
# Letra: i
# Letra: e
# Letra: l
# Letra:
# Letra: d
# Letra: a
# Letra:
# Letra: K
# Letra: e
# Letra: n
# Letra: z
# Letra: i
# Letra: e

# %%
def soma()
  pass
# Out:
#   File "<ipython-input-47-2204ff2c6221>", line 1
#     def soma()
#               ^
# SyntaxError: invalid syntax

# %%
len(zombies)
# Out:
# 4

# %% [markdown]
# Removendo um elemento específico de uma lista

# %%
zombies[:3]
print(zombies)
del zombies[2] # está linha remove o elemento
print(zombies)
# Out:
# ['z1', 'z2', 'z4']
# ['z1', 'z2']

# %%
nome[::-1]
# Out:
# 'eizneK ad leinaD'

# %%
numeros_em_tuplas = (1,2,3,4,5)
print(numeros_em_tuplas)
# Out:
# (1, 2, 3, 4, 5)

# %%
lista1.sort(reverse=True)
lista1
# Out:
# [40, 30, 20, 10]
