# %%
def include(arr,item):
        if item in arr:
            return True
        else:
            return False

# %%
def monkey_count(n):
    #your code here
    contar = []
    for i in range(n):
        contar.append(i+1)
        
    return contar
