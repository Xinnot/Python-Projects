# %%
def greet():
    return 'hello world!'

# %%
def square(n):
    return n*n

# %%
def multiply(a, b):
    return a * b

# %%
def add_five(num):
    total = num + 5
    return total

# %%
def main(verb, noun):
    return (verb + noun)

# %%
def summation(num):
    total = 0
    for i in range(1, num +1, 1):
        total += i
    return total
