# %%
bebidas = {
    "Jabroni": "Patron Tequila", 
    "School Counselor": "Anything with Alcohol", 
    "Programmer": "Hipster Craft Beer", 
    "Bike Gang Member": "Moonshine", 
    "Politician": "Your tax dollars",
    "Rapper": "Cristal", 
    "anything else": "Beer"}
    
def get_drink_by_profession(param):
    # code me!
    params = param.title()
    if params in bebidas:
        return bebidas[params]
    else:
        return "Beer"

# %%
frutas = {
    "melancia": {"quantidade": 4, "preco": 10},
    "pera": {"quantidade": 2, "preco": 3},
    "uva": {"quantidade": 8, "preco": 8},
    "ameixa": {"quantidade": 5, "preco": 2},
    "abacaxi": {"quantidade": 15, "preco": 4},
    "banana": {"quantidade": 6, "preco": 4}
}

for fruta in frutas.keys():
    print(fruta)

ex = {fruta: frutas[fruta]["preco"]}
print(ex)
# Out:
# melancia
# pera
# uva
# ameixa
# abacaxi
# banana
# {'banana': 4}
